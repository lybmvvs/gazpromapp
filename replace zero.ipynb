# %%
import pandas as pd
import numpy as np
import datetime

data = pd.read_excel('TYLE.xlsx', sheet_name='ГРП')
dummy = pd.read_excel('TYLE.xlsx', sheet_name='МЭР')
dummy.tail()
# Out:
#           Дата  Скважина №  Дебит жидкости, м3/сут  Дебит нефти, т/сут  \
# 302 2019-04-01          11                   123.0             12313.0
# 303 2019-05-01          11                    13.0               123.0
# 304 2020-01-01          11                123123.0                13.0
# 305 2021-01-01          11                  2131.0                 0.0
# 306 2021-02-01          11                 33131.0               123.0
#
#      Обводненность, %  Пластовое давление (ТР), атм  \
# 302          123123.0                           0.0
# 303          123123.0                           0.0
# 304          123123.0                           0.0
# 305           12331.0                         123.0
# 306              33.0                         123.0
#
#      Забойное давление (ТР), атм Пласт
# 302                          0.0    Ю3
# 303                          0.0    Ю3
# 304                          0.0    Ю3
# 305                       1231.0    Ю3
# 306                        123.0    Ю3

# %%
dummy["Пластовое давление (ТР), атм"] = dummy["Пластовое давление (ТР), атм"].replace(0, np.nan).bfill()
dummy
# Out:
#           Дата  Скважина №  Дебит жидкости, м3/сут  Дебит нефти, т/сут  \
# 0   2016-07-01           1                   78.60               55.39
# 1   2016-08-01           1                   84.36               59.86
# 2   2016-09-01           1                   85.34               68.98
# 3   2016-10-01           1                   88.41               71.09
# 4   2016-11-01           1                   79.03               62.62
# ..         ...         ...                     ...                 ...
# 302 2019-04-01          11                  123.00            12313.00
# 303 2019-05-01          11                   13.00              123.00
# 304 2020-01-01          11               123123.00               13.00
# 305 2021-01-01          11                 2131.00                0.00
# 306 2021-02-01          11                33131.00              123.00
#
#      Обводненность, %  Пластовое давление (ТР), атм  \
# 0               22.13                         263.0
# 1               21.52                         263.0
# 2                9.13                         263.0
# 3                9.67                         263.0
# 4               11.16                         263.0
# ..                ...                           ...
# 302         123123.00                         123.0
# 303         123123.00                         123.0
# 304         123123.00                         123.0
# 305          12331.00                         123.0
# 306             33.00                         123.0
#
#      Забойное давление (ТР), атм Пласт
# 0                          131.1    Ю3
# 1                          118.3    Ю3
# 2                          107.1    Ю3
# 3                           94.8    Ю3
# 4                           79.4    Ю3
# ..                           ...   ...
# 302                          0.0    Ю3
# 303                          0.0    Ю3
# 304                          0.0    Ю3
# 305                       1231.0    Ю3
# 306                        123.0    Ю3
#
# [307 rows x 8 columns]
